# %%
from mixed_data import create_pipeline

# %%
import pandas as pd
file = pd.read_csv("cirrhosis.csv")
file
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              NaN  24472   F     NaN          NaN
# 414  415    1103      C              NaN  14245   F     NaN          NaN
# 415  416    1055      C              NaN  20819   F     NaN          NaN
# 416  417     691      C              NaN  21185   F     NaN          NaN
# 417  418     976      C              NaN  19358   F     NaN          NaN
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0         Y     Y       14.5        261.0     2.60   156.0    1718.0  137.95
# 1         Y     N        1.1        302.0     4.14    54.0    7394.8  113.52
# 2         N     S        1.4        176.0     3.48   210.0     516.0   96.10
# 3         Y     S        1.8        244.0     2.54    64.0    6121.8   60.63
# 4         Y     N        3.4        279.0     3.53   143.0     671.0  113.15
# ..      ...   ...        ...          ...      ...     ...       ...     ...
# 413     NaN     N        1.2          NaN     2.96     NaN       NaN     NaN
# 414     NaN     N        0.9          NaN     3.83     NaN       NaN     NaN
# 415     NaN     N        1.6          NaN     3.42     NaN       NaN     NaN
# 416     NaN     N        0.8          NaN     3.75     NaN       NaN     NaN
# 417     NaN     N        0.7          NaN     3.29     NaN       NaN     NaN
#
#      Tryglicerides  Platelets  Prothrombin  Stage
# 0            172.0      190.0         12.2    4.0
# 1             88.0      221.0         10.6    3.0
# 2             55.0      151.0         12.0    4.0
# 3             92.0      183.0         10.3    4.0
# 4             72.0      136.0         10.9    3.0
# ..             ...        ...          ...    ...
# 413            NaN      174.0         10.9    3.0
# 414            NaN      180.0         11.2    4.0
# 415            NaN      143.0          9.9    3.0
# 416            NaN      269.0         10.4    3.0
# 417            NaN      350.0         10.6    4.0
#
# [418 rows x 20 columns]

# %%
file.Age = file.Age.apply(lambda x : round((x / 365), 0))
file.Status = file.Status.map(lambda x: "High chance" if x == "C" else ("Low chance" if x == "D" else "Transplant needed"))

# %%
from sklearn.model_selection import train_test_split

data, labels = file.drop(columns=["ID", "N_Days", "Status"]), file.Status
train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size=0.1, random_state=0, stratify=labels)

train_data.shape, test_data.shape, train_labels.shape, test_labels.shape
# Out:
# ((376, 17), (42, 17), (376,), (42,))

# %%
for column in train_data.columns:
    if train_data[column].dtype == "object":
        train_data[column] = train_data[column].dropna().astype("str").astype("category")

train_data.Stage = train_data.Stage.dropna().astype("str").astype("category")
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 376 entries, 196 to 221
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Drug           284 non-null    category
#  1   Age            376 non-null    float64
#  2   Sex            376 non-null    category
#  3   Ascites        284 non-null    category
#  4   Hepatomegaly   284 non-null    category
#  5   Spiders        284 non-null    category
#  6   Edema          376 non-null    category
#  7   Bilirubin      376 non-null    float64
#  8   Cholesterol    259 non-null    float64
#  9   Albumin        376 non-null    float64
#  10  Copper         282 non-null    float64
#  11  Alk_Phos       284 non-null    float64
#  12  SGOT           284 non-null    float64
#  13  Tryglicerides  257 non-null    float64
#  14  Platelets      366 non-null    float64
#  15  Prothrombin    375 non-null    float64
#  16  Stage          370 non-null    category
# dtypes: category(7), float64(10)
# memory usage: 35.8 KB

# %%
numeric_features = ['Age', 'Bilirubin', 'Cholesterol', 'Albumin', 'Copper',
                   'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets', 'Prothrombin']
categorical_unordered_features = ["Drug", "Sex"]
categorical_ordered_features = ["Ascites", "Hepatomegaly", "Spiders", "Edema", "Stage"]

# %%
param_grid_RandomForest = {
    "preprocessing__num__imputer__n_neighbors": range(3, 10),

    "feature_selector__k": range(1, 18),

    "oversampler__k_neighbors": range(3, 10, 2),
    "oversampler__borderline": [True, False],
    "undersampler__k_neighbors": range(3, 10, 2),
    
    "model__estimator__max_depth": range(2, 8),
    "model__estimator__criterion": ["gini", "entropy"],
}

param_grid_KNNeighbor = {
    "preprocessing__num__imputer__n_neighbors": range(3, 10),

    "feature_selector__k": range(1, 18),
    
    "oversampler__k_neighbors": range(3, 10, 2),
    "oversampler__borderline": [True, False],
    "undersampler__k_neighbors": range(3, 10, 2),
    
    "model__n_neighbors": range(3, 18, 2),
}

param_grid_AdaBoostGNB = {
    "preprocessing__num__imputer__n_neighbors": range(3, 10),

    "feature_selector__k": range(1, 18),
    
    "oversampler__k_neighbors": range(3, 10, 2),
    "oversampler__borderline": [True, False],
    "undersampler__k_neighbors": range(3, 10, 2),
    
    "model__learning_rate": [0.8, 0.9, 1, 1.1, 1.2, 1.3, 1.4, 1.5],
}

# %%
from sklearn.preprocessing import RobustScaler

clf_RandomForest = create_pipeline(
        numerical_features=numeric_features,
        categorical_unord_features=categorical_unordered_features,
        categorical_ord_features=categorical_ordered_features,
        imputers_needed=True,
        scaler=RobustScaler(),
        oversample_needed=True,
        oversampling_strategy={
            "Low chance": False,
            "Transplant needed": True
        },
        undersample_needed=True,
        undersampling_strategy=["High chance"],
        target=labels,
        model="MixedRandomForest"
    )

clf_KNNeighbor = create_pipeline(
        numerical_features=numeric_features,
        categorical_unord_features=categorical_unordered_features,
        categorical_ord_features=categorical_ordered_features,
        imputers_needed=True,
        scaler=RobustScaler(),
        oversample_needed=True,
        oversampling_strategy={
            "Low chance": False,
            "Transplant needed": True
        },
        undersample_needed=True,
        undersampling_strategy=["High chance"],
        target=labels,
        model="MixedKNN"
    )

clf_AdaBoostGNB = create_pipeline(
        numerical_features=numeric_features,
        categorical_unord_features=categorical_unordered_features,
        categorical_ord_features=categorical_ordered_features,
        imputers_needed=True,
        scaler=RobustScaler(),
        oversample_needed=True,
        oversampling_strategy={
            "Low chance": False,
            "Transplant needed": True
        },
        undersample_needed=True,
        undersampling_strategy=["High chance"],
        target=labels,
        model="AdaBoostMixedGaussianNB"
    )

# %%
clf_RandomForest
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    CustomKNNImputer(train_labels=0             Low chance
# 1            High chance
# 2             Low chance
# 3             Low chance
# 4      Transplant needed
#              ...
# 413           Low chance
# 414          High chance
# 415          High chance
# 416          High chance
# 417          High chance
# Name: Status, Length: 418, dtype: object)),
#                                                                   ('scaler',
#                                                                    RobustScaler())]),
#                                                   ['Age', 'Bilirubin',
#                                                    'Cholestero...
#                            continuous_features=['Age', 'Bilirubin',
#                                                 'Cholesterol', 'Albumin',
#                                                 'Copper', 'Alk_Phos', 'SGOT',
#                                                 'Tryglicerides', 'Platelets',
#                                                 'Prothrombin'],
#                            sampling_strategy={'Low chance': False,
#                                               'Transplant needed': True})),
#                 ('undersampler',
#                  MixedEditedNearestNeighbors(sampling_strategy=['High '
#                                                                 'chance'])),
#                 ('model',
#                  BaggingClassifier(estimator=MixedDecisionTree(),
#                                    n_estimators=30, n_jobs=-1,
#                                    random_state=0))])

# %%
clf_KNNeighbor
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    CustomKNNImputer(train_labels=0             Low chance
# 1            High chance
# 2             Low chance
# 3             Low chance
# 4      Transplant needed
#              ...
# 413           Low chance
# 414          High chance
# 415          High chance
# 416          High chance
# 417          High chance
# Name: Status, Length: 418, dtype: object)),
#                                                                   ('scaler',
#                                                                    RobustScaler())]),
#                                                   ['Age', 'Bilirubin',
#                                                    'Cholestero...
#                  SMOTE_ENC(categorical_features=['Drug', 'Sex', 'Ascites',
#                                                  'Hepatomegaly', 'Spiders',
#                                                  'Edema', 'Stage'],
#                            continuous_features=['Age', 'Bilirubin',
#                                                 'Cholesterol', 'Albumin',
#                                                 'Copper', 'Alk_Phos', 'SGOT',
#                                                 'Tryglicerides', 'Platelets',
#                                                 'Prothrombin'],
#                            sampling_strategy={'Low chance': False,
#                                               'Transplant needed': True})),
#                 ('undersampler',
#                  MixedEditedNearestNeighbors(sampling_strategy=['High '
#                                                                 'chance'])),
#                 ('model', MixedKNN())])

# %%
clf_AdaBoostGNB
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    CustomKNNImputer(train_labels=0             Low chance
# 1            High chance
# 2             Low chance
# 3             Low chance
# 4      Transplant needed
#              ...
# 413           Low chance
# 414          High chance
# 415          High chance
# 416          High chance
# 417          High chance
# Name: Status, Length: 418, dtype: object)),
#                                                                   ('scaler',
#                                                                    RobustScaler())]),
#                                                   ['Age', 'Bilirubin',
#                                                    'Cholestero...
#                            continuous_features=['Age', 'Bilirubin',
#                                                 'Cholesterol', 'Albumin',
#                                                 'Copper', 'Alk_Phos', 'SGOT',
#                                                 'Tryglicerides', 'Platelets',
#                                                 'Prothrombin'],
#                            sampling_strategy={'Low chance': False,
#                                               'Transplant needed': True})),
#                 ('undersampler',
#                  MixedEditedNearestNeighbors(sampling_strategy=['High '
#                                                                 'chance'])),
#                 ('model',
#                  AdaBoostClassifier(algorithm='SAMME',
#                                     estimator=MixedGaussianNB(),
#                                     random_state=0))])

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns

# %%
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
scorer = "f1_macro"

# %%
clfrf = RandomizedSearchCV(
    estimator = clf_RandomForest, 
    param_distributions=param_grid_RandomForest,
    cv = skf,
    scoring = scorer,
    n_jobs=-1,
    random_state=0,
    n_iter=10,
    error_score="raise"
)
clfrf.fit(train_data, train_labels)

best_params = clfrf.best_params_
print("Random Forest best parameters:", best_params)

f_macro_scores1 = []
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
for fold, (train_index, test_index) in enumerate(skf.split(train_data, train_labels)):
    X_fold_train, X_fold_valid = train_data.iloc[train_index], train_data.iloc[test_index]
    y_fold_train, y_fold_valid = train_labels.iloc[train_index], train_labels.iloc[test_index]

    y_pred = clfrf.predict(X_fold_valid)

    cm = confusion_matrix(y_fold_valid, y_pred)
    report = classification_report(y_fold_valid, y_pred, output_dict=False)
    print(report)
    report = classification_report(y_fold_valid, y_pred, output_dict=True)
    f_macro_scores1.append(report["macro avg"]["f1-score"])

    sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', ax=axes[fold // 5, fold % 5])
    axes[fold // 5, fold % 5].set_title(f'Fold {fold+1}')
    axes[fold // 5, fold % 5].set_xlabel('Predicted')
    axes[fold // 5, fold % 5].set_ylabel('True')

plt.tight_layout()
plt.show()
# Out:
# Random Forest best parameters: {'undersampler__k_neighbors': 9, 'preprocessing__num__imputer__n_neighbors': 7, 'oversampler__k_neighbors': 7, 'oversampler__borderline': False, 'model__estimator__max_depth': 6, 'model__estimator__criterion': 'entropy', 'feature_selector__k': 8}
#                    precision    recall  f1-score   support
#
#       High chance       0.95      1.00      0.98        21
#        Low chance       1.00      0.93      0.97        15
# Transplant needed       1.00      1.00      1.00         2
#
#          accuracy                           0.97        38
#         macro avg       0.98      0.98      0.98        38
#      weighted avg       0.97      0.97      0.97        38
#
#                    precision    recall  f1-score   support
#
#       High chance       0.95      1.00      0.98        21
#        Low chance       1.00      0.93      0.97        15
# Transplant needed       1.00      1.00      1.00         2
#
#          accuracy                           0.97        38
#         macro avg       0.98      0.98      0.98        38
#      weighted avg       0.97      0.97      0.97        38
#
#                    precision    recall  f1-score   support
#
#       High chance       1.00      0.95      0.98        21
#        Low chance       0.94      1.00      0.97        15
# Transplant needed       1.00      1.00      1.00         2
#
#          accuracy                           0.97        38
#         macro avg       0.98      0.98      0.98        38
#      weighted avg       0.98      0.97      0.97        38
#
#                    precision    recall  f1-score   support
#
#       High chance       0.91      1.00      0.95        21
#        Low chance       1.00      0.87      0.93        15
# Transplant needed       1.00      1.00      1.00         2
#
#          accuracy                           0.95        38
#         macro avg       0.97      0.96      0.96        38
#      weighted avg       0.95      0.95      0.95        38
#
#                    precision    recall  f1-score   support
#
#       High chance       0.91      0.95      0.93        21
#        Low chance       0.92      0.86      0.89        14
# Transplant needed       1.00      1.00      1.00         3
#
#          accuracy                           0.92        38
#         macro avg       0.94      0.94      0.94        38
#      weighted avg       0.92      0.92      0.92        38
#
#                    precision    recall  f1-score   support
#
#       High chance       1.00      1.00      1.00        21
#        Low chance       1.00      0.93      0.96        14
# Transplant needed       0.75      1.00      0.86         3
#
#          accuracy                           0.97        38
#         macro avg       0.92      0.98      0.94        38
#      weighted avg       0.98      0.97      0.98        38
#
#                    precision    recall  f1-score   support
#
#       High chance       0.95      0.95      0.95        21
#        Low chance       1.00      0.86      0.92        14
# Transplant needed       0.50      1.00      0.67         2
#
#          accuracy                           0.92        37
#         macro avg       0.82      0.94      0.85        37
#      weighted avg       0.95      0.92      0.93        37
#
#                    precision    recall  f1-score   support
#
#       High chance       0.95      1.00      0.98        21
#        Low chance       1.00      0.93      0.96        14
# Transplant needed       1.00      1.00      1.00         2
#
#          accuracy                           0.97        37
#         macro avg       0.98      0.98      0.98        37
#      weighted avg       0.97      0.97      0.97        37
#
#                    precision    recall  f1-score   support
#
#       High chance       0.91      1.00      0.95        21
#        Low chance       1.00      0.79      0.88        14
# Transplant needed       0.67      1.00      0.80         2
#
#          accuracy                           0.92        37
#         macro avg       0.86      0.93      0.88        37
#      weighted avg       0.93      0.92      0.92        37
#
#                    precision    recall  f1-score   support
#
#       High chance       1.00      1.00      1.00        20
#        Low chance       1.00      1.00      1.00        15
# Transplant needed       1.00      1.00      1.00         2
#
#          accuracy                           1.00        37
#         macro avg       1.00      1.00      1.00        37
#      weighted avg       1.00      1.00      1.00        37

# %%
clfknn = RandomizedSearchCV(
    estimator = clf_KNNeighbor, 
    param_distributions=param_grid_KNNeighbor,
    cv = skf,
    scoring = scorer,
    n_jobs=-1,
    random_state=0,
    n_iter=10,
)
clfknn.fit(train_data, train_labels)

best_params = clfknn.best_params_
print("KNN best parameters:", best_params)

f_macro_scores2 = []
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
for fold, (train_index, test_index) in enumerate(skf.split(train_data, train_labels)):
    X_fold_train, X_fold_valid = train_data.iloc[train_index], train_data.iloc[test_index]
    y_fold_train, y_fold_valid = train_labels.iloc[train_index], train_labels.iloc[test_index]

    y_pred = clfknn.predict(X_fold_valid)

    cm = confusion_matrix(y_fold_valid, y_pred)
    report = classification_report(y_fold_valid, y_pred, output_dict=False)
    print(report)
    report = classification_report(y_fold_valid, y_pred, output_dict=True)
    f_macro_scores2.append(report["macro avg"]["f1-score"])

    sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', ax=axes[fold // 5, fold % 5])
    axes[fold // 5, fold % 5].set_title(f'Fold {fold+1}')
    axes[fold // 5, fold % 5].set_xlabel('Predicted')
    axes[fold // 5, fold % 5].set_ylabel('True')

plt.tight_layout()
plt.show()
# Out:
# KNN best parameters: {'undersampler__k_neighbors': 3, 'preprocessing__num__imputer__n_neighbors': 8, 'oversampler__k_neighbors': 5, 'oversampler__borderline': False, 'model__n_neighbors': 17, 'feature_selector__k': 11}
#                    precision    recall  f1-score   support
#
#       High chance       0.90      0.86      0.88        21
#        Low chance       0.90      0.60      0.72        15
# Transplant needed       0.25      1.00      0.40         2
#
#          accuracy                           0.76        38
#         macro avg       0.68      0.82      0.67        38
#      weighted avg       0.87      0.76      0.79        38
#
#                    precision    recall  f1-score   support
#
#       High chance       0.89      0.81      0.85        21
#        Low chance       1.00      0.40      0.57        15
# Transplant needed       0.15      1.00      0.27         2
#
#          accuracy                           0.66        38
#         macro avg       0.68      0.74      0.56        38
#      weighted avg       0.90      0.66      0.71        38
#
#                    precision    recall  f1-score   support
#
#       High chance       0.84      0.76      0.80        21
#        Low chance       0.77      0.67      0.71        15
# Transplant needed       0.33      1.00      0.50         2
#
#          accuracy                           0.74        38
#         macro avg       0.65      0.81      0.67        38
#      weighted avg       0.79      0.74      0.75        38
#
#                    precision    recall  f1-score   support
#
#       High chance       1.00      0.67      0.80        21
#        Low chance       0.75      0.80      0.77        15
# Transplant needed       0.12      0.50      0.20         2
#
#          accuracy                           0.71        38
#         macro avg       0.62      0.66      0.59        38
#      weighted avg       0.86      0.71      0.76        38
#
#                    precision    recall  f1-score   support
#
#       High chance       0.89      0.81      0.85        21
#        Low chance       0.78      0.50      0.61        14
# Transplant needed       0.30      1.00      0.46         3
#
#          accuracy                           0.71        38
#         macro avg       0.66      0.77      0.64        38
#      weighted avg       0.80      0.71      0.73        38
#
#                    precision    recall  f1-score   support
#
#       High chance       0.89      0.76      0.82        21
#        Low chance       0.77      0.71      0.74        14
# Transplant needed       0.29      0.67      0.40         3
#
#          accuracy                           0.74        38
#         macro avg       0.65      0.71      0.65        38
#      weighted avg       0.80      0.74      0.76        38
#
#                    precision    recall  f1-score   support
#
#       High chance       0.78      0.67      0.72        21
#        Low chance       0.89      0.57      0.70        14
# Transplant needed       0.20      1.00      0.33         2
#
#          accuracy                           0.65        37
#         macro avg       0.62      0.75      0.58        37
#      weighted avg       0.79      0.65      0.69        37
#
#                    precision    recall  f1-score   support
#
#       High chance       0.88      0.67      0.76        21
#        Low chance       0.69      0.64      0.67        14
# Transplant needed       0.12      0.50      0.20         2
#
#          accuracy                           0.65        37
#         macro avg       0.56      0.60      0.54        37
#      weighted avg       0.77      0.65      0.69        37
#
#                    precision    recall  f1-score   support
#
#       High chance       0.83      0.90      0.86        21
#        Low chance       0.88      0.50      0.64        14
# Transplant needed       0.17      0.50      0.25         2
#
#          accuracy                           0.73        37
#         macro avg       0.62      0.63      0.58        37
#      weighted avg       0.81      0.73      0.74        37
#
#                    precision    recall  f1-score   support
#
#       High chance       0.90      0.90      0.90        20
#        Low chance       0.92      0.73      0.81        15
# Transplant needed       0.40      1.00      0.57         2
#
#          accuracy                           0.84        37
#         macro avg       0.74      0.88      0.76        37
#      weighted avg       0.88      0.84      0.85        37

# %%
clfadagnb = RandomizedSearchCV(
    estimator = clf_AdaBoostGNB, 
    param_distributions=param_grid_AdaBoostGNB,
    cv = skf,
    scoring = scorer,
    n_jobs=-1,
    random_state=0,
    n_iter=10,
)
clfadagnb.fit(train_data, train_labels)

best_params = clfadagnb.best_params_
print("AdaBoost best parameters:", best_params)

f_macro_scores3 = []
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
for fold, (train_index, test_index) in enumerate(skf.split(train_data, train_labels)):
    X_fold_train, X_fold_valid = train_data.iloc[train_index], train_data.iloc[test_index]
    y_fold_train, y_fold_valid = train_labels.iloc[train_index], train_labels.iloc[test_index]

    y_pred = clfadagnb.predict(X_fold_valid)

    cm = confusion_matrix(y_fold_valid, y_pred)
    report = classification_report(y_fold_valid, y_pred, output_dict=False)
    print(report)
    report = classification_report(y_fold_valid, y_pred, output_dict=True)
    f_macro_scores3.append(report["macro avg"]["f1-score"])

    sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', ax=axes[fold // 5, fold % 5])
    axes[fold // 5, fold % 5].set_title(f'Fold {fold+1}')
    axes[fold // 5, fold % 5].set_xlabel('Predicted')
    axes[fold // 5, fold % 5].set_ylabel('True')

plt.tight_layout()
plt.show()
# Out:
# AdaBoost best parameters: {'undersampler__k_neighbors': 9, 'preprocessing__num__imputer__n_neighbors': 7, 'oversampler__k_neighbors': 3, 'oversampler__borderline': False, 'model__learning_rate': 1, 'feature_selector__k': 8}
#                    precision    recall  f1-score   support
#
#       High chance       0.79      0.90      0.84        21
#        Low chance       0.89      0.53      0.67        15
# Transplant needed       0.40      1.00      0.57         2
#
#          accuracy                           0.76        38
#         macro avg       0.69      0.81      0.69        38
#      weighted avg       0.81      0.76      0.76        38
#
#                    precision    recall  f1-score   support
#
#       High chance       0.74      0.81      0.77        21
#        Low chance       0.89      0.53      0.67        15
# Transplant needed       0.33      1.00      0.50         2
#
#          accuracy                           0.71        38
#         macro avg       0.65      0.78      0.65        38
#      weighted avg       0.78      0.71      0.72        38
#
#                    precision    recall  f1-score   support
#
#       High chance       0.70      0.67      0.68        21
#        Low chance       0.69      0.60      0.64        15
# Transplant needed       0.40      1.00      0.57         2
#
#          accuracy                           0.66        38
#         macro avg       0.60      0.76      0.63        38
#      weighted avg       0.68      0.66      0.66        38
#
#                    precision    recall  f1-score   support
#
#       High chance       0.85      0.81      0.83        21
#        Low chance       0.75      0.80      0.77        15
# Transplant needed       0.00      0.00      0.00         2
#
#          accuracy                           0.76        38
#         macro avg       0.53      0.54      0.53        38
#      weighted avg       0.77      0.76      0.76        38
#
#                    precision    recall  f1-score   support
#
#       High chance       0.77      0.81      0.79        21
#        Low chance       0.70      0.50      0.58        14
# Transplant needed       0.50      1.00      0.67         3
#
#          accuracy                           0.71        38
#         macro avg       0.66      0.77      0.68        38
#      weighted avg       0.72      0.71      0.70        38
#
#                    precision    recall  f1-score   support
#
#       High chance       0.80      0.76      0.78        21
#        Low chance       0.83      0.71      0.77        14
# Transplant needed       0.17      0.33      0.22         3
#
#          accuracy                           0.71        38
#         macro avg       0.60      0.60      0.59        38
#      weighted avg       0.76      0.71      0.73        38
#
#                    precision    recall  f1-score   support
#
#       High chance       0.78      0.86      0.82        21
#        Low chance       0.89      0.57      0.70        14
# Transplant needed       0.40      1.00      0.57         2
#
#          accuracy                           0.76        37
#         macro avg       0.69      0.81      0.70        37
#      weighted avg       0.80      0.76      0.76        37
#
#                    precision    recall  f1-score   support
#
#       High chance       0.82      0.67      0.74        21
#        Low chance       0.67      0.71      0.69        14
# Transplant needed       0.20      0.50      0.29         2
#
#          accuracy                           0.68        37
#         macro avg       0.56      0.63      0.57        37
#      weighted avg       0.73      0.68      0.69        37
#
#                    precision    recall  f1-score   support
#
#       High chance       0.83      0.90      0.86        21
#        Low chance       1.00      0.43      0.60        14
# Transplant needed       0.12      0.50      0.20         2
#
#          accuracy                           0.70        37
#         macro avg       0.65      0.61      0.55        37
#      weighted avg       0.85      0.70      0.73        37
#
#                    precision    recall  f1-score   support
#
#       High chance       0.95      0.90      0.92        20
#        Low chance       0.87      0.87      0.87        15
# Transplant needed       0.67      1.00      0.80         2
#
#          accuracy                           0.89        37
#         macro avg       0.83      0.92      0.86        37
#      weighted avg       0.90      0.89      0.89        37

# %%
cv_scores = {
    'RandomForest': f_macro_scores1,
    'KNNeighbor': f_macro_scores2,
    'ADABOOST(NBC)': f_macro_scores3
}

df_cv_scores = pd.DataFrame(cv_scores)

df_cv_scores.boxplot()
plt.xticks(ticks=range(1, len(df_cv_scores.columns) + 1), labels=df_cv_scores.columns, rotation=90)
plt.tight_layout()
plt.show()

# %%
import scipy.stats as stats

sns.kdeplot(data=df_cv_scores)
plt.tight_layout()
plt.show()
# Out:
# C:\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
for i, col in enumerate(df_cv_scores.columns):
    stats.probplot(df_cv_scores[col], plot=plt)
    plt.title(f'QQ Plot - {col}')
    plt.xlabel('Normal distribution quantiles')
    plt.ylabel('Data quantiles')
    plt.tight_layout()

    plt.show()

# %%
statistic, p_value = stats.levene(cv_scores["RandomForest"], 
                                 cv_scores["KNNeighbor"], 
                                 cv_scores["ADABOOST(NBC)"])

print("Levene's statistic:", statistic)
print("p value:", p_value)

if p_value < 0.05:
    print("There is evidence to reject the null hypothesis of equal variances.")
else:
    print("There is no evidence to reject the null hypothesis of equal variances.")
# Out:
# Levene's statistic: 1.2839640149733114
# p value: 0.2933112820310237
# There is no evidence to reject the null hypothesis of equal variances.

# %%
from scipy.stats import kruskal
from itertools import combinations
from scipy.stats import wilcoxon

kruskal_result = kruskal(cv_scores["RandomForest"], 
                         cv_scores["KNNeighbor"], 
                         cv_scores["ADABOOST(NBC)"])

print("Kruskal-Wallis statistic:", kruskal_result.statistic)
print("p value:", kruskal_result.pvalue)

if kruskal_result.pvalue < 0.05:
    print("There is a statistically relevant difference between at least two groups.")
    models = ["RandomForest", "KNNeighbor", "ADABOOST(NBC)"]
    couples = list(combinations(models, 2))
    
    for _ in couples:
        m1, m2 = _
        wilcoxon_result = wilcoxon(cv_scores[m1], cv_scores[m2])
        
        print("Comparing", m1, "and", m2)
        print("Wilcoxon statistic:", wilcoxon_result.statistic)
        print("p value:", wilcoxon_result.pvalue)
        
        if wilcoxon_result.pvalue < 0.05:
            print("There is a statistically relevant difference between", m1, "and", m2)
        else:
            print("There is no statistically relevant difference between", m1, "and", m2)
        print("----")
else:
    print("There are no statistically relevant difference between groups.")
# Out:
# Kruskal-Wallis statistic: 19.051980418335575
# p value: 7.293147843738438e-05
# There is a statistically relevant difference between at least two groups.
# Comparing RandomForest and KNNeighbor
# Wilcoxon statistic: 0.0
# p value: 0.001953125
# There is a statistically relevant difference between RandomForest and KNNeighbor
# ----
# Comparing RandomForest and ADABOOST(NBC)
# Wilcoxon statistic: 0.0
# p value: 0.001953125
# There is a statistically relevant difference between RandomForest and ADABOOST(NBC)
# ----
# Comparing KNNeighbor and ADABOOST(NBC)
# Wilcoxon statistic: 19.0
# p value: 0.431640625
# There is no statistically relevant difference between KNNeighbor and ADABOOST(NBC)
# ----

# %%
for column in test_data.columns:
    if test_data[column].dtype == "object":
        test_data[column] = test_data[column].dropna().astype("str").astype("category")

test_data.Stage = test_data.Stage.dropna().astype("str").astype("category")

# %%
y_pred = clfrf.predict(test_data)

report = classification_report(test_labels, y_pred, output_dict=False)
print(report)

cm = confusion_matrix(test_labels, y_pred)
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g')
# Out:
#                    precision    recall  f1-score   support
#
#       High chance       0.71      0.87      0.78        23
#        Low chance       0.73      0.50      0.59        16
# Transplant needed       0.33      0.33      0.33         3
#
#          accuracy                           0.69        42
#         macro avg       0.59      0.57      0.57        42
#      weighted avg       0.69      0.69      0.68        42
# <Axes: >
